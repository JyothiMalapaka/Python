# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
DIR= './kaggledata'
FILE='/train_v2.csv'

file='{}{}'.format(DIR,FILE)
print(file)
# Out:
# ./kaggledata/train_v2.csv

# %%
df=pd.read_csv(file,nrows=5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   channelGrouping       5 non-null      object
#  1   customDimensions      5 non-null      object
#  2   date                  5 non-null      int64
#  3   device                5 non-null      object
#  4   fullVisitorId         5 non-null      int64
#  5   geoNetwork            5 non-null      object
#  6   hits                  5 non-null      object
#  7   socialEngagementType  5 non-null      object
#  8   totals                5 non-null      object
#  9   trafficSource         5 non-null      object
#  10  visitId               5 non-null      int64
#  11  visitNumber           5 non-null      int64
#  12  visitStartTime        5 non-null      int64
# dtypes: int64(5), object(8)
# memory usage: 648.0+ bytes

# %% [markdown]
# # Read the train_v2.csv file - random rows to get closer to sample data with workable size

# %%
import pandas as pd
import random

DIR= './kaggledata'
FILE='/train_v2.csv'

file='{}{}'.format(DIR,FILE)

n = 31458337
s = 5000000 #desired sample size


skip = sorted(random.sample(range(1,n+1),n-s)) #the 0-indexed header will not be included in the skip list

df = pd.read_csv(file, converters={'device':json.loads, 'geoNetwork':json.loads, 'totals':json.loads, 'trafficSource':json.loads},header=0,skiprows=skip)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   channelGrouping       270955 non-null  object
#  1   customDimensions      270955 non-null  object
#  2   date                  270955 non-null  int64
#  3   device                270955 non-null  object
#  4   fullVisitorId         270955 non-null  object
#  5   geoNetwork            270955 non-null  object
#  6   hits                  270955 non-null  object
#  7   socialEngagementType  270955 non-null  object
#  8   totals                270955 non-null  object
#  9   trafficSource         270955 non-null  object
#  10  visitId               270955 non-null  int64
#  11  visitNumber           270955 non-null  int64
#  12  visitStartTime        270955 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 26.9+ MB

# %%
df
# Out:
#    channelGrouping                              customDimensions      date  \
# 0   Organic Search    [{'index': '4', 'value': 'North America'}]  20171130
# 1   Organic Search             [{'index': '4', 'value': 'EMEA'}]  20161213
# 2         Referral    [{'index': '4', 'value': 'North America'}]  20180221
# 3           Social  [{'index': '4', 'value': 'Central America'}]  20180302
# 4           Social    [{'index': '4', 'value': 'North America'}]  20180217
# 5   Organic Search    [{'index': '4', 'value': 'North America'}]  20180228
# 6       Affiliates             [{'index': '4', 'value': 'EMEA'}]  20160805
# 7   Organic Search    [{'index': '4', 'value': 'South America'}]  20170925
# 8         Referral    [{'index': '4', 'value': 'North America'}]  20171226
# 9           Direct    [{'index': '4', 'value': 'North America'}]  20171226
# 10          Social             [{'index': '4', 'value': 'EMEA'}]  20170308
# 11          Social                                            []  20161117
# 12  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20161117
# 13          Social             [{'index': '4', 'value': 'EMEA'}]  20161107
# 14  Organic Search    [{'index': '4', 'value': 'North America'}]  20160821
# 15  Organic Search                                            []  20161208
# 16          Direct             [{'index': '4', 'value': 'APAC'}]  20161127
# 17  Organic Search    [{'index': '4', 'value': 'North America'}]  20170922
# 18  Organic Search    [{'index': '4', 'value': 'North America'}]  20161203
# 19  Organic Search    [{'index': '4', 'value': 'North America'}]  20180405
# 20  Organic Search             [{'index': '4', 'value': 'APAC'}]  20170607
# 21      Affiliates             [{'index': '4', 'value': 'APAC'}]  20180416
# 22          Social             [{'index': '4', 'value': 'APAC'}]  20180109
# 23  Organic Search    [{'index': '4', 'value': 'North America'}]  20180406
# 24         Display    [{'index': '4', 'value': 'North America'}]  20180201
# 25  Organic Search    [{'index': '4', 'value': 'North America'}]  20170601
# 26          Direct    [{'index': '4', 'value': 'North America'}]  20170108
# 27  Organic Search    [{'index': '4', 'value': 'North America'}]  20180213
# 28         Display    [{'index': '4', 'value': 'North America'}]  20170907
# 29          Direct             [{'index': '4', 'value': 'EMEA'}]  20170125
# 30  Organic Search             [{'index': '4', 'value': 'APAC'}]  20170523
# 31  Organic Search    [{'index': '4', 'value': 'South America'}]  20170328
# 32  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20170707
# 33  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171104
# 34          Direct             [{'index': '4', 'value': 'APAC'}]  20161218
# 35          Social             [{'index': '4', 'value': 'EMEA'}]  20180111
# 36  Organic Search             [{'index': '4', 'value': 'APAC'}]  20161006
# 37          Direct             [{'index': '4', 'value': 'EMEA'}]  20171204
# 38          Social                                            []  20161119
# 39  Organic Search    [{'index': '4', 'value': 'North America'}]  20170301
# 40  Organic Search    [{'index': '4', 'value': 'North America'}]  20171223
# 41  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20180215
# 42  Organic Search    [{'index': '4', 'value': 'North America'}]  20161214
# 43  Organic Search  [{'index': '4', 'value': 'Central America'}]  20161004
# 44          Direct    [{'index': '4', 'value': 'North America'}]  20171117
# 45          Direct             [{'index': '4', 'value': 'APAC'}]  20171231
# 46          Direct    [{'index': '4', 'value': 'North America'}]  20180404
# 47  Organic Search                                            []  20171101
# 48  Organic Search                                            []  20161005
# 49          Direct    [{'index': '4', 'value': 'North America'}]  20170104
#
#                                                device        fullVisitorId  \
# 0   {'browser': 'Firefox', 'browserVersion': 'not ...  3346831532083173726
# 1   {'browser': 'Safari', 'browserVersion': 'not a...   124772744218476433
# 2   {'browser': 'Chrome', 'browserVersion': 'not a...  2078818331430817585
# 3   {'browser': 'Chrome', 'browserVersion': 'not a...  4064455864480786560
# 4   {'browser': 'Chrome', 'browserVersion': 'not a...  5846665915970870292
# 5   {'browser': 'Chrome', 'browserVersion': 'not a...   867502490171202064
# 6   {'browser': 'Chrome', 'browserVersion': 'not a...  3505408521162821672
# 7   {'browser': 'Firefox', 'browserVersion': 'not ...  2655423105075350531
# 8   {'browser': 'Chrome', 'browserVersion': 'not a...   925526874044092477
# 9   {'browser': 'Chrome', 'browserVersion': 'not a...  7403583986213641513
# 10  {'browser': 'Safari', 'browserVersion': 'not a...  6094615518178037632
# 11  {'browser': 'Safari', 'browserVersion': 'not a...  3718226304172125284
# 12  {'browser': 'Chrome', 'browserVersion': 'not a...  1456898519067367467
# 13  {'browser': 'Chrome', 'browserVersion': 'not a...  9820821902405932959
# 14  {'browser': 'Chrome', 'browserVersion': 'not a...  7901747624361009743
# 15  {'browser': 'Safari', 'browserVersion': 'not a...  7264808664464760562
# 16  {'browser': 'Opera', 'browserVersion': 'not av...  9014541154514085972
# 17  {'browser': 'Firefox', 'browserVersion': 'not ...  3548025839074169475
# 18  {'browser': 'Chrome', 'browserVersion': 'not a...  5331162086803374420
# 19  {'browser': 'Chrome', 'browserVersion': 'not a...  1597130633109207908
# 20  {'browser': 'Chrome', 'browserVersion': 'not a...  7918508089283298398
# 21  {'browser': 'Chrome', 'browserVersion': 'not a...  1347202016929674216
# 22  {'browser': 'Chrome', 'browserVersion': 'not a...  6707452186686215173
# 23  {'browser': 'Chrome', 'browserVersion': 'not a...  5300335374973143813
# 24  {'browser': 'Chrome', 'browserVersion': 'not a...  8057299029664870170
# 25  {'browser': 'Chrome', 'browserVersion': 'not a...  6373982314870105098
# 26  {'browser': 'Chrome', 'browserVersion': 'not a...  3345848435852564190
# 27  {'browser': 'Safari', 'browserVersion': 'not a...   511512956972078994
# 28  {'browser': 'Chrome', 'browserVersion': 'not a...  4693827936575754114
# 29  {'browser': 'Chrome', 'browserVersion': 'not a...  2482335945171032510
# 30  {'browser': 'Chrome', 'browserVersion': 'not a...  2153105853160930607
# 31  {'browser': 'Chrome', 'browserVersion': 'not a...  6010762115416457536
# 32  {'browser': 'Chrome', 'browserVersion': 'not a...   610627544592293877
# 33  {'browser': 'Samsung Internet', 'browserVersio...  7651437824845085000
# 34  {'browser': 'Safari', 'browserVersion': 'not a...   627415058810810755
# 35  {'browser': 'Chrome', 'browserVersion': 'not a...   690867148764432193
# 36  {'browser': 'Chrome', 'browserVersion': 'not a...  3924369657210279737
# 37  {'browser': 'Internet Explorer', 'browserVersi...  4371234797809848128
# 38  {'browser': 'Chrome', 'browserVersion': 'not a...   720311197761340948
# 39  {'browser': 'Chrome', 'browserVersion': 'not a...  5704804393306746013
# 40  {'browser': 'Internet Explorer', 'browserVersi...  4273314006927540560
# 41  {'browser': 'Chrome', 'browserVersion': 'not a...  7629562591463517851
# 42  {'browser': 'Internet Explorer', 'browserVersi...  8172954801638962156
# 43  {'browser': 'Chrome', 'browserVersion': 'not a...  4279601641571842628
# 44  {'browser': 'Chrome', 'browserVersion': 'not a...  3531547490132808102
# 45  {'browser': 'Chrome', 'browserVersion': 'not a...  9985009896570434613
# 46  {'browser': 'Chrome', 'browserVersion': 'not a...  1327643246910577375
# 47  {'browser': 'Chrome', 'browserVersion': 'not a...  3611965666076638006
# 48  {'browser': 'Chrome', 'browserVersion': 'not a...   769445598064116887
# 49  {'browser': 'Chrome', 'browserVersion': 'not a...   657048414788149963
#
#                                            geoNetwork  \
# 0   {'continent': 'Americas', 'subContinent': 'Nor...
# 1   {'continent': 'Europe', 'subContinent': 'Weste...
# 2   {'continent': 'Americas', 'subContinent': 'Nor...
# 3   {'continent': 'Americas', 'subContinent': 'Cen...
# 4   {'continent': 'Americas', 'subContinent': 'Nor...
# 5   {'continent': 'Americas', 'subContinent': 'Nor...
# 6   {'continent': 'Europe', 'subContinent': 'North...
# 7   {'continent': 'Americas', 'subContinent': 'Sou...
# 8   {'continent': 'Americas', 'subContinent': 'Nor...
# 9   {'continent': 'Americas', 'subContinent': 'Nor...
# 10  {'continent': 'Asia', 'subContinent': 'Western...
# 11  {'continent': 'Europe', 'subContinent': 'Easte...
# 12  {'continent': 'Europe', 'subContinent': 'Easte...
# 13  {'continent': 'Asia', 'subContinent': 'Western...
# 14  {'continent': 'Americas', 'subContinent': 'Nor...
# 15  {'continent': 'Europe', 'subContinent': 'North...
# 16  {'continent': 'Asia', 'subContinent': 'Southea...
# 17  {'continent': 'Americas', 'subContinent': 'Nor...
# 18  {'continent': 'Americas', 'subContinent': 'Nor...
# 19  {'continent': 'Americas', 'subContinent': 'Nor...
# 20  {'continent': 'Asia', 'subContinent': 'Southea...
# 21  {'continent': 'Oceania', 'subContinent': 'Aust...
# 22  {'continent': 'Asia', 'subContinent': 'Eastern...
# 23  {'continent': 'Americas', 'subContinent': 'Nor...
# 24  {'continent': 'Americas', 'subContinent': 'Nor...
# 25  {'continent': 'Americas', 'subContinent': 'Nor...
# 26  {'continent': 'Americas', 'subContinent': 'Nor...
# 27  {'continent': 'Americas', 'subContinent': 'Nor...
# 28  {'continent': 'Americas', 'subContinent': 'Nor...
# 29  {'continent': 'Europe', 'subContinent': 'North...
# 30  {'continent': 'Asia', 'subContinent': 'Souther...
# 31  {'continent': 'Americas', 'subContinent': 'Sou...
# 32  {'continent': 'Europe', 'subContinent': 'South...
# 33  {'continent': 'Europe', 'subContinent': 'South...
# 34  {'continent': 'Asia', 'subContinent': 'Eastern...
# 35  {'continent': 'Europe', 'subContinent': 'South...
# 36  {'continent': 'Asia', 'subContinent': 'Souther...
# 37  {'continent': 'Europe', 'subContinent': 'North...
# 38  {'continent': 'Asia', 'subContinent': 'Western...
# 39  {'continent': 'Americas', 'subContinent': 'Nor...
# 40  {'continent': 'Americas', 'subContinent': 'Nor...
# 41  {'continent': 'Europe', 'subContinent': 'Easte...
# 42  {'continent': 'Americas', 'subContinent': 'Nor...
# 43  {'continent': 'Americas', 'subContinent': 'Cen...
# 44  {'continent': 'Americas', 'subContinent': 'Nor...
# 45  {'continent': 'Asia', 'subContinent': 'Eastern...
# 46  {'continent': 'Americas', 'subContinent': 'Nor...
# 47  {'continent': 'Americas', 'subContinent': 'Sou...
# 48  {'continent': 'Asia', 'subContinent': 'Eastern...
# 49  {'continent': 'Americas', 'subContinent': 'Nor...
#
#                                                  hits  socialEngagementType  \
# 0   [{'hitNumber': '1', 'time': '0', 'hour': '14',...  Not Socially Engaged
# 1   [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 2   [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 3   [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 4   [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 5   [{'hitNumber': '1', 'time': '0', 'hour': '20',...  Not Socially Engaged
# 6   [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 7   [{'hitNumber': '1', 'time': '0', 'hour': '20',...  Not Socially Engaged
# 8   [{'hitNumber': '1', 'time': '0', 'hour': '20',...  Not Socially Engaged
# 9   [{'hitNumber': '1', 'time': '0', 'hour': '13',...  Not Socially Engaged
# 10  [{'hitNumber': '1', 'time': '0', 'hour': '0', ...  Not Socially Engaged
# 11  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 12  [{'hitNumber': '1', 'time': '0', 'hour': '1', ...  Not Socially Engaged
# 13  [{'hitNumber': '1', 'time': '0', 'hour': '3', ...  Not Socially Engaged
# 14  [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 15  [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 16  [{'hitNumber': '1', 'time': '0', 'hour': '9', ...  Not Socially Engaged
# 17  [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 18  [{'hitNumber': '1', 'time': '0', 'hour': '16',...  Not Socially Engaged
# 19  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 20  [{'hitNumber': '1', 'time': '0', 'hour': '20',...  Not Socially Engaged
# 21  [{'hitNumber': '1', 'time': '0', 'hour': '22',...  Not Socially Engaged
# 22  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...  Not Socially Engaged
# 23  [{'hitNumber': '1', 'time': '0', 'hour': '16',...  Not Socially Engaged
# 24  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 25  [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 26  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 27  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...  Not Socially Engaged
# 28  [{'hitNumber': '1', 'time': '0', 'hour': '16',...  Not Socially Engaged
# 29  [{'hitNumber': '1', 'time': '0', 'hour': '13',...  Not Socially Engaged
# 30  [{'hitNumber': '1', 'time': '0', 'hour': '6', ...  Not Socially Engaged
# 31  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 32  [{'hitNumber': '1', 'time': '0', 'hour': '14',...  Not Socially Engaged
# 33  [{'hitNumber': '1', 'time': '0', 'hour': '9', ...  Not Socially Engaged
# 34  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 35  [{'hitNumber': '1', 'time': '0', 'hour': '14',...  Not Socially Engaged
# 36  [{'hitNumber': '1', 'time': '0', 'hour': '3', ...  Not Socially Engaged
# 37  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 38  [{'hitNumber': '1', 'time': '0', 'hour': '2', ...  Not Socially Engaged
# 39  [{'hitNumber': '1', 'time': '0', 'hour': '14',...  Not Socially Engaged
# 40  [{'hitNumber': '1', 'time': '0', 'hour': '18',...  Not Socially Engaged
# 41  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 42  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 43  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 44  [{'hitNumber': '1', 'time': '0', 'hour': '2', ...  Not Socially Engaged
# 45  [{'hitNumber': '1', 'time': '0', 'hour': '19',...  Not Socially Engaged
# 46  [{'hitNumber': '1', 'time': '0', 'hour': '8', ...  Not Socially Engaged
# 47  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 48  [{'hitNumber': '1', 'time': '0', 'hour': '18',...  Not Socially Engaged
# 49  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
#
#                                                totals  \
# 0   {'visits': '1', 'hits': '20', 'pageviews': '12...
# 1   {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 2   {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 3   {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 4   {'visits': '1', 'hits': '9', 'pageviews': '7',...
# 5   {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 6   {'visits': '1', 'hits': '3', 'pageviews': '2',...
# 7   {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 8   {'visits': '1', 'hits': '6', 'pageviews': '6',...
# 9   {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 10  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 11  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 12  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 13  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 14  {'visits': '1', 'hits': '5', 'pageviews': '5',...
# 15  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 16  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 17  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 18  {'visits': '1', 'hits': '3', 'pageviews': '3',...
# 19  {'visits': '1', 'hits': '3', 'pageviews': '3',...
# 20  {'visits': '1', 'hits': '4', 'pageviews': '4',...
# 21  {'visits': '1', 'hits': '8', 'pageviews': '8',...
# 22  {'visits': '1', 'hits': '6', 'pageviews': '6',...
# 23  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 24  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 25  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 26  {'visits': '1', 'hits': '7', 'pageviews': '7',...
# 27  {'visits': '1', 'hits': '9', 'pageviews': '7',...
# 28  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 29  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 30  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 31  {'visits': '1', 'hits': '9', 'pageviews': '9',...
# 32  {'visits': '1', 'hits': '3', 'pageviews': '3',...
# 33  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 34  {'visits': '1', 'hits': '3', 'pageviews': '3',...
# 35  {'visits': '1', 'hits': '4', 'pageviews': '4',...
# 36  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 37  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 38  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 39  {'visits': '1', 'hits': '4', 'pageviews': '2',...
# 40  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 41  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 42  {'visits': '1', 'hits': '23', 'pageviews': '16...
# 43  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 44  {'visits': '1', 'hits': '7', 'pageviews': '6',...
# 45  {'visits': '1', 'hits': '21', 'pageviews': '20...
# 46  {'visits': '1', 'hits': '6', 'pageviews': '6',...
# 47  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 48  {'visits': '1', 'hits': '1', 'pageviews': '1',...
# 49  {'visits': '1', 'hits': '1', 'pageviews': '1',...
#
#                                         trafficSource     visitId  \
# 0   {'campaign': '(not set)', 'source': 'google', ...  1512080782
# 1   {'campaign': '(not set)', 'source': '(direct)'...  1481646121
# 2   {'referralPath': '/', 'campaign': '(not set)',...  1519278246
# 3   {'referralPath': '/intl/es-419/yt/about/copyri...  1520008479
# 4   {'referralPath': '/yt/music/index.html', 'camp...  1518899669
# 5   {'campaign': '(not set)', 'source': 'google', ...  1519877838
# 6   {'campaign': 'Data Share Promo', 'source': 'Pa...  1470408127
# 7   {'campaign': '(not set)', 'source': 'google', ...  1506397802
# 8   {'referralPath': '/', 'campaign': '(not set)',...  1514349858
# 9   {'campaign': '(not set)', 'source': '(direct)'...  1514322542
# 10  {'referralPath': '/yt/about/', 'campaign': '(n...  1488962481
# 11  {'referralPath': '/yt/about/ro/', 'campaign': ...  1479412848
# 12  {'campaign': '(not set)', 'source': '(direct)'...  1479375398
# 13  {'referralPath': '/yt/about/tr/', 'campaign': ...  1478517827
# 14  {'campaign': '(not set)', 'source': 'google', ...  1471791880
# 15  {'campaign': '(not set)', 'source': '(direct)'...  1481213901
# 16  {'campaign': '(not set)', 'source': '(direct)'...  1480266031
# 17  {'campaign': '(not set)', 'source': 'google', ...  1506141631
# 18  {'campaign': '(not set)', 'source': '(direct)'...  1480812160
# 19  {'campaign': '(not set)', 'source': 'google', ...  1522937636
# 20  {'campaign': '(not set)', 'source': '(direct)'...  1496893604
# 21  {'campaign': 'Data Share Promo', 'source': 'Pa...  1523942101
# 22  {'referralPath': '/yt/creators/', 'campaign': ...  1515507710
# 23  {'campaign': '(not set)', 'source': 'google', ...  1523058145
# 24  {'campaign': '(not set)', 'source': 'dfa', 'me...  1517516067
# 25  {'campaign': '(not set)', 'source': 'google', ...  1496331279
# 26  {'campaign': '(not set)', 'source': '(direct)'...  1483948176
# 27  {'campaign': '(not set)', 'source': 'google', ...  1518530501
# 28  {'campaign': '1000557 | GA | US | en | Hybrid ...  1504827395
# 29  {'campaign': '(not set)', 'source': '(direct)'...  1485380750
# 30  {'campaign': '(not set)', 'source': 'google', ...  1495545992
# 31  {'campaign': '(not set)', 'source': 'google', ...  1490720870
# 32  {'campaign': '(not set)', 'source': 'google', ...  1499462534
# 33  {'campaign': '(not set)', 'source': 'google', ...  1509812309
# 34  {'campaign': '(not set)', 'source': '(direct)'...  1482133712
# 35  {'referralPath': '/intl/it/yt/about/', 'campai...  1515709634
# 36  {'campaign': '(not set)', 'source': '(direct)'...  1475751527
# 37  {'campaign': '(not set)', 'source': '(direct)'...  1512402455
# 38  {'referralPath': '/', 'campaign': '(not set)',...  1479552172
# 39  {'campaign': '(not set)', 'source': 'google', ...  1488405881
# 40  {'campaign': '(not set)', 'source': 'google', ...  1514082293
# 41  {'campaign': '(not set)', 'source': 'google', ...  1518707159
# 42  {'campaign': '(not set)', 'source': '(direct)'...  1481746759
# 43  {'campaign': '(not set)', 'source': '(direct)'...  1475602190
# 44  {'campaign': '(not set)', 'source': '(direct)'...  1510914280
# 45  {'campaign': '(not set)', 'source': '(direct)'...  1514775836
# 46  {'campaign': '(not set)', 'source': '(direct)'...  1522855678
# 47  {'campaign': '(not set)', 'source': 'google', ...  1509546456
# 48  {'campaign': '(not set)', 'source': '(direct)'...  1475719060
# 49  {'campaign': '(not set)', 'source': '(direct)'...  1483543843
#
#     visitNumber  visitStartTime
# 0             1      1512080782
# 1             1      1481646121
# 2             3      1519278246
# 3             1      1520008479
# 4             1      1518899669
# 5             1      1519877838
# 6             1      1470408127
# 7             1      1506397802
# 8             5      1514349858
# 9             2      1514322542
# 10            1      1488962481
# 11            1      1479412848
# 12            1      1479375398
# 13            1      1478517827
# 14            1      1471791880
# 15            1      1481213901
# 16            1      1480266031
# 17            1      1506141631
# 18            1      1480812160
# 19            1      1522937636
# 20            1      1496893604
# 21            1      1523942101
# 22            1      1515507710
# 23            1      1523058145
# 24            1      1517516067
# 25            1      1496331279
# 26            1      1483948176
# 27            1      1518530501
# 28            1      1504827395
# 29            2      1485380750
# 30            1      1495545992
# 31            1      1490720870
# 32            1      1499462534
# 33            1      1509812309
# 34            1      1482133712
# 35            3      1515709634
# 36            1      1475751527
# 37           17      1512402455
# 38           37      1479552172
# 39            1      1488405881
# 40            1      1514082293
# 41            1      1518707159
# 42            1      1481746759
# 43            1      1475602190
# 44            1      1510914280
# 45            1      1514775836
# 46            3      1522855678
# 47            1      1509546456
# 48            1      1475719060
# 49            1      1483543843

# %% [markdown]
# # Convert the json fields to columns

# %%
df=pd.concat([df, df['device'].apply(pd.Series)], axis=1)
df=pd.concat([df, df['geoNetwork'].apply(pd.Series)], axis=1)
df=pd.concat([df, df['totals'].apply(pd.Series)], axis=1)
df=pd.concat([df, df['trafficSource'].apply(pd.Series)], axis=1)

# %%
df.info()
pd.set_option('display.max_columns', None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   channelGrouping            270955 non-null  object
#  1   customDimensions           270955 non-null  object
#  2   date                       270955 non-null  int64
#  3   device                     270955 non-null  object
#  4   fullVisitorId              270955 non-null  object
#  5   geoNetwork                 270955 non-null  object
#  6   hits_1                     270955 non-null  object
#  7   socialEngagementType       270955 non-null  object
#  8   totals                     270955 non-null  object
#  9   trafficSource              270955 non-null  object
#  10  visitId                    270955 non-null  int64
#  11  visitNumber                270955 non-null  int64
#  12  visitStartTime             270955 non-null  int64
#  13  browser                    270955 non-null  object
#  14  browserVersion             270955 non-null  object
#  15  browserSize                270955 non-null  object
#  16  operatingSystem            270955 non-null  object
#  17  operatingSystemVersion     270955 non-null  object
#  18  isMobile                   270955 non-null  bool
#  19  mobileDeviceBranding       270955 non-null  object
#  20  mobileDeviceModel          270955 non-null  object
#  21  mobileInputSelector        270955 non-null  object
#  22  mobileDeviceInfo           270955 non-null  object
#  23  mobileDeviceMarketingName  270955 non-null  object
#  24  flashVersion               270955 non-null  object
#  25  language                   270955 non-null  object
#  26  screenColors               270955 non-null  object
#  27  screenResolution           270955 non-null  object
#  28  deviceCategory             270955 non-null  object
#  29  continent                  270955 non-null  object
#  30  subContinent               270955 non-null  object
#  31  country                    270955 non-null  object
#  32  region                     270955 non-null  object
#  33  metro                      270955 non-null  object
#  34  city                       270955 non-null  object
#  35  cityId                     270955 non-null  object
#  36  networkDomain              270955 non-null  object
#  37  latitude                   270955 non-null  object
#  38  longitude                  270955 non-null  object
#  39  networkLocation            270955 non-null  object
#  40  visits                     270955 non-null  object
#  41  hits_2                     270955 non-null  int32
#  42  pageviews                  270907 non-null  object
#  43  timeOnSite                 132262 non-null  object
#  44  newVisits                  207457 non-null  object
#  45  sessionQualityDim          138297 non-null  object
#  46  transactions               2963 non-null    object
#  47  transactionRevenue         2955 non-null    object
#  48  totalTransactionRevenue    2955 non-null    object
#  49  bounces                    138231 non-null  object
#  50  campaign                   270955 non-null  object
#  51  source                     270955 non-null  object
#  52  medium                     270955 non-null  object
#  53  keyword                    104123 non-null  object
#  54  adwordsClickInfo           270955 non-null  object
#  55  isTrueDirect               84477 non-null   object
#  56  referralPath               89732 non-null   object
#  57  adContent                  10303 non-null   object
# dtypes: bool(1), int32(1), int64(4), object(52)
# memory usage: 117.1+ MB

# %% [markdown]
# # Visualisation for getting better idea of the fields

# %%
for column in df.columns:
    
    if column == 'hits':
        cols.append(f'hits_{count}')
        count+=1
        continue

# %%
df['hits_2']=df['hits_2'].astype('int32')

# %%
df['channelGrouping'].unique()
# Out:
# array(['Organic Search', 'Paid Search', 'Referral', 'Direct', 'Display',
#        'Social', 'Affiliates', '(Other)'], dtype=object)

# %%
df['date'].max() # min - 20160801 , max 20180430
# Out:
# 20180430

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search  [{'index': '4', 'value': 'North America'}]  20171016
# 1  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {'browser': 'Chrome', 'browserVersion': 'not a...  7058083259448191057
# 1  {'browser': 'Safari', 'browserVersion': 'not a...  9592294493127192752
# 2  {'browser': 'UC Browser', 'browserVersion': 'n...  6338477365942527347
# 3  {'browser': 'Chrome', 'browserVersion': 'not a...  0579247845938461901
# 4  {'browser': 'Chrome', 'browserVersion': 'not a...  0875141984250977091
#
#                                           geoNetwork  \
# 0  {'continent': 'Americas', 'subContinent': 'Nor...
# 1  {'continent': 'Europe', 'subContinent': 'North...
# 2  {'continent': 'Asia', 'subContinent': 'Souther...
# 3  {'continent': 'Europe', 'subContinent': 'North...
# 4  {'continent': 'Asia', 'subContinent': 'Eastern...
#
#                                               hits_1  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '16',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
#
#                                               totals  \
# 0  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 1  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 2  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 3  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 4  {'visits': '1', 'hits': '2', 'pageviews': '2',...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {'campaign': '(not set)', 'source': 'google', ...  1508174145            1
# 1  {'campaign': '(not set)', 'source': 'google', ...  1508197277            1
# 2  {'campaign': '(not set)', 'source': 'google', ...  1508177911            1
# 3  {'campaign': '(not set)', 'source': 'google', ...  1508165231            1
# 4  {'campaign': '(not set)', 'source': 'google', ...  1508223135            1
#
#    visitStartTime     browser                 browserVersion  \
# 0      1508174145      Chrome  not available in demo dataset
# 1      1508197277      Safari  not available in demo dataset
# 2      1508177911  UC Browser  not available in demo dataset
# 3      1508165231      Chrome  not available in demo dataset
# 4      1508223135      Chrome  not available in demo dataset
#
#                      browserSize operatingSystem  \
# 0  not available in demo dataset         Windows
# 1  not available in demo dataset       Macintosh
# 2  not available in demo dataset         Android
# 3  not available in demo dataset         Windows
# 4  not available in demo dataset           Linux
#
#           operatingSystemVersion  isMobile           mobileDeviceBranding  \
# 0  not available in demo dataset     False  not available in demo dataset
# 1  not available in demo dataset     False  not available in demo dataset
# 2  not available in demo dataset      True  not available in demo dataset
# 3  not available in demo dataset     False  not available in demo dataset
# 4  not available in demo dataset     False  not available in demo dataset
#
#                mobileDeviceModel            mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 mobileDeviceInfo      mobileDeviceMarketingName  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     flashVersion                       language  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     screenColors               screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   deviceCategory continent      subContinent         country  \
# 0        desktop  Americas  Northern America          Canada
# 1        desktop    Europe   Northern Europe  United Kingdom
# 2         mobile      Asia     Southern Asia           India
# 3        desktop    Europe   Northern Europe  United Kingdom
# 4        desktop      Asia      Eastern Asia          Taiwan
#
#                           region                          metro  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                             city                         cityId networkDomain  \
# 0  not available in demo dataset  not available in demo dataset     (not set)
# 1  not available in demo dataset  not available in demo dataset   virginm.net
# 2  not available in demo dataset  not available in demo dataset     (not set)
# 3  not available in demo dataset  not available in demo dataset   virginm.net
# 4  not available in demo dataset  not available in demo dataset   nthu.edu.tw
#
#                         latitude                      longitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  networkLocation visits  hits_2 pageviews timeOnSite  \
# 0  not available in demo dataset      1       2         2       1266
# 1  not available in demo dataset      1       2         2         11
# 2  not available in demo dataset      1       2         2         73
# 3  not available in demo dataset      1       2         2         26
# 4  not available in demo dataset      1       2         2         31
#
#   newVisits sessionQualityDim transactions transactionRevenue  \
# 0         1                 1          NaN                NaN
# 1         1                 1          NaN                NaN
# 2         1                 1          NaN                NaN
# 3         1                 1          NaN                NaN
# 4         1                 1          NaN                NaN
#
#   totalTransactionRevenue bounces   campaign  source   medium         keyword  \
# 0                     NaN     NaN  (not set)  google  organic  (not provided)
# 1                     NaN     NaN  (not set)  google  organic  (not provided)
# 2                     NaN     NaN  (not set)  google  organic  (not provided)
# 3                     NaN     NaN  (not set)  google  organic  (not provided)
# 4                     NaN     NaN  (not set)  google  organic  (not provided)
#
#                                     adwordsClickInfo isTrueDirect  \
# 0  {'criteriaParameters': 'not available in demo ...          NaN
# 1  {'criteriaParameters': 'not available in demo ...          NaN
# 2  {'criteriaParameters': 'not available in demo ...          NaN
# 3  {'criteriaParameters': 'not available in demo ...          NaN
# 4  {'criteriaParameters': 'not available in demo ...          NaN
#
#   referralPath adContent
# 0          NaN       NaN
# 1          NaN       NaN
# 2          NaN       NaN
# 3          NaN       NaN
# 4          NaN       NaN

# %%
df['socialEngagementType'].value_counts()
# Out:
# Not Socially Engaged    270955
# Name: socialEngagementType, dtype: int64

# %%
df['customDimensions_1'] = df['customDimensions_1'].replace("'", "\"")

# %%
df['customDimensions_1']=df['customDimensions_1'].str.replace(']', '', regex=False)
df['customDimensions_1']=df['customDimensions_1'].str.replace('[', '', regex=False)

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search  [{'index': '4', 'value': 'North America'}]  20171016
# 1  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {'browser': 'Chrome', 'browserVersion': 'not a...  7058083259448191057
# 1  {'browser': 'Safari', 'browserVersion': 'not a...  9592294493127192752
# 2  {'browser': 'UC Browser', 'browserVersion': 'n...  6338477365942527347
# 3  {'browser': 'Chrome', 'browserVersion': 'not a...  0579247845938461901
# 4  {'browser': 'Chrome', 'browserVersion': 'not a...  0875141984250977091
#
#                                           geoNetwork  \
# 0  {'continent': 'Americas', 'subContinent': 'Nor...
# 1  {'continent': 'Europe', 'subContinent': 'North...
# 2  {'continent': 'Asia', 'subContinent': 'Souther...
# 3  {'continent': 'Europe', 'subContinent': 'North...
# 4  {'continent': 'Asia', 'subContinent': 'Eastern...
#
#                                               hits_1  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '16',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
#
#                                               totals  \
# 0  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 1  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 2  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 3  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 4  {'visits': '1', 'hits': '2', 'pageviews': '2',...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {'campaign': '(not set)', 'source': 'google', ...  1508174145            1
# 1  {'campaign': '(not set)', 'source': 'google', ...  1508197277            1
# 2  {'campaign': '(not set)', 'source': 'google', ...  1508177911            1
# 3  {'campaign': '(not set)', 'source': 'google', ...  1508165231            1
# 4  {'campaign': '(not set)', 'source': 'google', ...  1508223135            1
#
#    visitStartTime     browser                 browserVersion  \
# 0      1508174145      Chrome  not available in demo dataset
# 1      1508197277      Safari  not available in demo dataset
# 2      1508177911  UC Browser  not available in demo dataset
# 3      1508165231      Chrome  not available in demo dataset
# 4      1508223135      Chrome  not available in demo dataset
#
#                      browserSize operatingSystem  \
# 0  not available in demo dataset         Windows
# 1  not available in demo dataset       Macintosh
# 2  not available in demo dataset         Android
# 3  not available in demo dataset         Windows
# 4  not available in demo dataset           Linux
#
#           operatingSystemVersion  isMobile           mobileDeviceBranding  \
# 0  not available in demo dataset     False  not available in demo dataset
# 1  not available in demo dataset     False  not available in demo dataset
# 2  not available in demo dataset      True  not available in demo dataset
# 3  not available in demo dataset     False  not available in demo dataset
# 4  not available in demo dataset     False  not available in demo dataset
#
#                mobileDeviceModel            mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 mobileDeviceInfo      mobileDeviceMarketingName  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     flashVersion                       language  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     screenColors               screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   deviceCategory continent      subContinent         country  \
# 0        desktop  Americas  Northern America          Canada
# 1        desktop    Europe   Northern Europe  United Kingdom
# 2         mobile      Asia     Southern Asia           India
# 3        desktop    Europe   Northern Europe  United Kingdom
# 4        desktop      Asia      Eastern Asia          Taiwan
#
#                           region                          metro  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                             city                         cityId networkDomain  \
# 0  not available in demo dataset  not available in demo dataset     (not set)
# 1  not available in demo dataset  not available in demo dataset   virginm.net
# 2  not available in demo dataset  not available in demo dataset     (not set)
# 3  not available in demo dataset  not available in demo dataset   virginm.net
# 4  not available in demo dataset  not available in demo dataset   nthu.edu.tw
#
#                         latitude                      longitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  networkLocation visits  hits_2 pageviews timeOnSite  \
# 0  not available in demo dataset      1       2         2       1266
# 1  not available in demo dataset      1       2         2         11
# 2  not available in demo dataset      1       2         2         73
# 3  not available in demo dataset      1       2         2         26
# 4  not available in demo dataset      1       2         2         31
#
#   newVisits sessionQualityDim transactions transactionRevenue  \
# 0         1                 1          NaN                NaN
# 1         1                 1          NaN                NaN
# 2         1                 1          NaN                NaN
# 3         1                 1          NaN                NaN
# 4         1                 1          NaN                NaN
#
#   totalTransactionRevenue bounces   campaign  source   medium         keyword  \
# 0                     NaN     NaN  (not set)  google  organic  (not provided)
# 1                     NaN     NaN  (not set)  google  organic  (not provided)
# 2                     NaN     NaN  (not set)  google  organic  (not provided)
# 3                     NaN     NaN  (not set)  google  organic  (not provided)
# 4                     NaN     NaN  (not set)  google  organic  (not provided)
#
#                                     adwordsClickInfo isTrueDirect  \
# 0  {'criteriaParameters': 'not available in demo ...          NaN
# 1  {'criteriaParameters': 'not available in demo ...          NaN
# 2  {'criteriaParameters': 'not available in demo ...          NaN
# 3  {'criteriaParameters': 'not available in demo ...          NaN
# 4  {'criteriaParameters': 'not available in demo ...          NaN
#
#   referralPath adContent                        customDimensions_1
# 0          NaN       NaN  {'index': '4', 'value': 'North America'}
# 1          NaN       NaN           {'index': '4', 'value': 'EMEA'}
# 2          NaN       NaN           {'index': '4', 'value': 'APAC'}
# 3          NaN       NaN           {'index': '4', 'value': 'EMEA'}
# 4          NaN       NaN           {'index': '4', 'value': 'APAC'}

# %%
df=pd.concat([df, df['adwordsClickInfo'].apply(pd.Series)], axis=1)

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search  [{'index': '4', 'value': 'North America'}]  20171016
# 1  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 2  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
# 3  Organic Search           [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search           [{'index': '4', 'value': 'APAC'}]  20171016
#
#                                               device        fullVisitorId  \
# 0  {'browser': 'Chrome', 'browserVersion': 'not a...  7058083259448191057
# 1  {'browser': 'Safari', 'browserVersion': 'not a...  9592294493127192752
# 2  {'browser': 'UC Browser', 'browserVersion': 'n...  6338477365942527347
# 3  {'browser': 'Chrome', 'browserVersion': 'not a...  0579247845938461901
# 4  {'browser': 'Chrome', 'browserVersion': 'not a...  0875141984250977091
#
#                                           geoNetwork  \
# 0  {'continent': 'Americas', 'subContinent': 'Nor...
# 1  {'continent': 'Europe', 'subContinent': 'North...
# 2  {'continent': 'Asia', 'subContinent': 'Souther...
# 3  {'continent': 'Europe', 'subContinent': 'North...
# 4  {'continent': 'Asia', 'subContinent': 'Eastern...
#
#                                               hits_1  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '16',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '7', ...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
#
#                                               totals  \
# 0  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 1  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 2  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 3  {'visits': '1', 'hits': '2', 'pageviews': '2',...
# 4  {'visits': '1', 'hits': '2', 'pageviews': '2',...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {'campaign': '(not set)', 'source': 'google', ...  1508174145            1
# 1  {'campaign': '(not set)', 'source': 'google', ...  1508197277            1
# 2  {'campaign': '(not set)', 'source': 'google', ...  1508177911            1
# 3  {'campaign': '(not set)', 'source': 'google', ...  1508165231            1
# 4  {'campaign': '(not set)', 'source': 'google', ...  1508223135            1
#
#    visitStartTime     browser                 browserVersion  \
# 0      1508174145      Chrome  not available in demo dataset
# 1      1508197277      Safari  not available in demo dataset
# 2      1508177911  UC Browser  not available in demo dataset
# 3      1508165231      Chrome  not available in demo dataset
# 4      1508223135      Chrome  not available in demo dataset
#
#                      browserSize operatingSystem  \
# 0  not available in demo dataset         Windows
# 1  not available in demo dataset       Macintosh
# 2  not available in demo dataset         Android
# 3  not available in demo dataset         Windows
# 4  not available in demo dataset           Linux
#
#           operatingSystemVersion  isMobile           mobileDeviceBranding  \
# 0  not available in demo dataset     False  not available in demo dataset
# 1  not available in demo dataset     False  not available in demo dataset
# 2  not available in demo dataset      True  not available in demo dataset
# 3  not available in demo dataset     False  not available in demo dataset
# 4  not available in demo dataset     False  not available in demo dataset
#
#                mobileDeviceModel            mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 mobileDeviceInfo      mobileDeviceMarketingName  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     flashVersion                       language  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     screenColors               screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   deviceCategory continent      subContinent         country  \
# 0        desktop  Americas  Northern America          Canada
# 1        desktop    Europe   Northern Europe  United Kingdom
# 2         mobile      Asia     Southern Asia           India
# 3        desktop    Europe   Northern Europe  United Kingdom
# 4        desktop      Asia      Eastern Asia          Taiwan
#
#                           region                          metro  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                             city                         cityId networkDomain  \
# 0  not available in demo dataset  not available in demo dataset     (not set)
# 1  not available in demo dataset  not available in demo dataset   virginm.net
# 2  not available in demo dataset  not available in demo dataset     (not set)
# 3  not available in demo dataset  not available in demo dataset   virginm.net
# 4  not available in demo dataset  not available in demo dataset   nthu.edu.tw
#
#                         latitude                      longitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  networkLocation visits  hits_2 pageviews timeOnSite  \
# 0  not available in demo dataset      1       2         2       1266
# 1  not available in demo dataset      1       2         2         11
# 2  not available in demo dataset      1       2         2         73
# 3  not available in demo dataset      1       2         2         26
# 4  not available in demo dataset      1       2         2         31
#
#   newVisits sessionQualityDim transactions transactionRevenue  \
# 0         1                 1          NaN                NaN
# 1         1                 1          NaN                NaN
# 2         1                 1          NaN                NaN
# 3         1                 1          NaN                NaN
# 4         1                 1          NaN                NaN
#
#   totalTransactionRevenue bounces   campaign  source   medium         keyword  \
# 0                     NaN     NaN  (not set)  google  organic  (not provided)
# 1                     NaN     NaN  (not set)  google  organic  (not provided)
# 2                     NaN     NaN  (not set)  google  organic  (not provided)
# 3                     NaN     NaN  (not set)  google  organic  (not provided)
# 4                     NaN     NaN  (not set)  google  organic  (not provided)
#
#                                     adwordsClickInfo isTrueDirect  \
# 0  {'criteriaParameters': 'not available in demo ...          NaN
# 1  {'criteriaParameters': 'not available in demo ...          NaN
# 2  {'criteriaParameters': 'not available in demo ...          NaN
# 3  {'criteriaParameters': 'not available in demo ...          NaN
# 4  {'criteriaParameters': 'not available in demo ...          NaN
#
#   referralPath adContent                        customDimensions_1  \
# 0          NaN       NaN  {'index': '4', 'value': 'North America'}
# 1          NaN       NaN           {'index': '4', 'value': 'EMEA'}
# 2          NaN       NaN           {'index': '4', 'value': 'APAC'}
# 3          NaN       NaN           {'index': '4', 'value': 'EMEA'}
# 4          NaN       NaN           {'index': '4', 'value': 'APAC'}
#
#               criteriaParameters page slot gclId adNetworkType isVideoAd  \
# 0  not available in demo dataset  NaN  NaN   NaN           NaN       NaN
# 1  not available in demo dataset  NaN  NaN   NaN           NaN       NaN
# 2  not available in demo dataset  NaN  NaN   NaN           NaN       NaN
# 3  not available in demo dataset  NaN  NaN   NaN           NaN       NaN
# 4  not available in demo dataset  NaN  NaN   NaN           NaN       NaN
#
#   targetingCriteria                    customDimensions_index
# 0               NaN  {'index': '4', 'value': 'North America'}
# 1               NaN           {'index': '4', 'value': 'EMEA'}
# 2               NaN           {'index': '4', 'value': 'APAC'}
# 3               NaN           {'index': '4', 'value': 'EMEA'}
# 4               NaN           {'index': '4', 'value': 'APAC'}

# %% [markdown]
# # Need to fix the customdimension error .. not able to parse it as a dictionary

# %%
df=pd.concat([df, ast.literal_eval(df['customDimensions_1'].apply(pd.Series))], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-375-fd6c90fa6bcb> in <module>
# ----> 1 df=pd.concat([df, ast.literal_eval(df['customDimensions_1'].apply(pd.Series))], axis=1)
#
# ~\anaconda3\lib\ast.py in literal_eval(node_or_string)
#      97                     return left - right
#      98         return _convert_signed_num(node)
# ---> 99     return _convert(node_or_string)
#     100
#     101
#
# ~\anaconda3\lib\ast.py in _convert(node)
#      96                 else:
#      97                     return left - right
# ---> 98         return _convert_signed_num(node)
#      99     return _convert(node_or_string)
#     100
#
# ~\anaconda3\lib\ast.py in _convert_signed_num(node)
#      73             else:
#      74                 return - operand
# ---> 75         return _convert_num(node)
#      76     def _convert(node):
#      77         if isinstance(node, Constant):
#
# ~\anaconda3\lib\ast.py in _convert_num(node)
#      64     def _convert_num(node):
#      65         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 66             _raise_malformed_node(node)
#      67         return node.value
#      68     def _convert_signed_num(node):
#
# ~\anaconda3\lib\ast.py in _raise_malformed_node(node)
#      61         node_or_string = node_or_string.body
#      62     def _raise_malformed_node(node):
# ---> 63         raise ValueError(f'malformed node or string: {node!r}')
#      64     def _convert_num(node):
#      65         if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
#
# ValueError: malformed node or string:                                                0
# 0       {'index': '4', 'value': 'North America'}
# 1                {'index': '4', 'value': 'EMEA'}
# 2                {'index': '4', 'value': 'APAC'}
# 3                {'index': '4', 'value': 'EMEA'}
# 4                {'index': '4', 'value': 'APAC'}
# ...                                          ...
# 270950
# 270951  {'index': '4', 'value': 'North America'}
# 270952
# 270953           {'index': '4', 'value': 'EMEA'}
# 270954
#
# [270955 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 67 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   channelGrouping            270955 non-null  object
#  1   customDimensions           270955 non-null  object
#  2   date                       270955 non-null  int64
#  3   device                     270955 non-null  object
#  4   fullVisitorId              270955 non-null  object
#  5   geoNetwork                 270955 non-null  object
#  6   hits_1                     270955 non-null  object
#  7   socialEngagementType       270955 non-null  object
#  8   totals                     270955 non-null  object
#  9   trafficSource              270955 non-null  object
#  10  visitId                    270955 non-null  int64
#  11  visitNumber                270955 non-null  int64
#  12  visitStartTime             270955 non-null  int64
#  13  browser                    270955 non-null  object
#  14  browserVersion             270955 non-null  object
#  15  browserSize                270955 non-null  object
#  16  operatingSystem            270955 non-null  object
#  17  operatingSystemVersion     270955 non-null  object
#  18  isMobile                   270955 non-null  bool
#  19  mobileDeviceBranding       270955 non-null  object
#  20  mobileDeviceModel          270955 non-null  object
#  21  mobileInputSelector        270955 non-null  object
#  22  mobileDeviceInfo           270955 non-null  object
#  23  mobileDeviceMarketingName  270955 non-null  object
#  24  flashVersion               270955 non-null  object
#  25  language                   270955 non-null  object
#  26  screenColors               270955 non-null  object
#  27  screenResolution           270955 non-null  object
#  28  deviceCategory             270955 non-null  object
#  29  continent                  270955 non-null  object
#  30  subContinent               270955 non-null  object
#  31  country                    270955 non-null  object
#  32  region                     270955 non-null  object
#  33  metro                      270955 non-null  object
#  34  city                       270955 non-null  object
#  35  cityId                     270955 non-null  object
#  36  networkDomain              270955 non-null  object
#  37  latitude                   270955 non-null  object
#  38  longitude                  270955 non-null  object
#  39  networkLocation            270955 non-null  object
#  40  visits                     270955 non-null  object
#  41  hits_2                     270955 non-null  int32
#  42  pageviews                  270907 non-null  object
#  43  timeOnSite                 132262 non-null  object
#  44  newVisits                  207457 non-null  object
#  45  sessionQualityDim          138297 non-null  object
#  46  transactions               2963 non-null    object
#  47  transactionRevenue         2955 non-null    object
#  48  totalTransactionRevenue    2955 non-null    object
#  49  bounces                    138231 non-null  object
#  50  campaign                   270955 non-null  object
#  51  source                     270955 non-null  object
#  52  medium                     270955 non-null  object
#  53  keyword                    104123 non-null  object
#  54  adwordsClickInfo           270955 non-null  object
#  55  isTrueDirect               84477 non-null   object
#  56  referralPath               89732 non-null   object
#  57  adContent                  10303 non-null   object
#  58  customDimensions_1         270955 non-null  object
#  59  criteriaParameters         270955 non-null  object
#  60  page                       11853 non-null   object
#  61  slot                       11853 non-null   object
#  62  gclId                      11882 non-null   object
#  63  adNetworkType              11853 non-null   object
#  64  isVideoAd                  11853 non-null   object
#  65  targetingCriteria          553 non-null     object
#  66  customDimensions_index     270955 non-null  object
# dtypes: bool(1), int32(1), int64(4), object(61)
# memory usage: 135.7+ MB

# %%
df=df.convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 67 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   channelGrouping            270955 non-null  string
#  1   customDimensions           270955 non-null  string
#  2   date                       270955 non-null  Int64
#  3   device                     270955 non-null  object
#  4   fullVisitorId              270955 non-null  object
#  5   geoNetwork                 270955 non-null  object
#  6   hits_1                     270955 non-null  string
#  7   socialEngagementType       270955 non-null  string
#  8   totals                     270955 non-null  object
#  9   trafficSource              270955 non-null  object
#  10  visitId                    270955 non-null  Int64
#  11  visitNumber                270955 non-null  Int64
#  12  visitStartTime             270955 non-null  Int64
#  13  browser                    270955 non-null  string
#  14  browserVersion             270955 non-null  string
#  15  browserSize                270955 non-null  string
#  16  operatingSystem            270955 non-null  string
#  17  operatingSystemVersion     270955 non-null  string
#  18  isMobile                   270955 non-null  boolean
#  19  mobileDeviceBranding       270955 non-null  string
#  20  mobileDeviceModel          270955 non-null  string
#  21  mobileInputSelector        270955 non-null  string
#  22  mobileDeviceInfo           270955 non-null  string
#  23  mobileDeviceMarketingName  270955 non-null  string
#  24  flashVersion               270955 non-null  string
#  25  language                   270955 non-null  string
#  26  screenColors               270955 non-null  string
#  27  screenResolution           270955 non-null  string
#  28  deviceCategory             270955 non-null  string
#  29  continent                  270955 non-null  string
#  30  subContinent               270955 non-null  string
#  31  country                    270955 non-null  string
#  32  region                     270955 non-null  string
#  33  metro                      270955 non-null  string
#  34  city                       270955 non-null  string
#  35  cityId                     270955 non-null  string
#  36  networkDomain              270955 non-null  string
#  37  latitude                   270955 non-null  string
#  38  longitude                  270955 non-null  string
#  39  networkLocation            270955 non-null  string
#  40  visits                     270955 non-null  string
#  41  hits_2                     270955 non-null  Int32
#  42  pageviews                  270907 non-null  string
#  43  timeOnSite                 132262 non-null  string
#  44  newVisits                  207457 non-null  string
#  45  sessionQualityDim          138297 non-null  string
#  46  transactions               2963 non-null    string
#  47  transactionRevenue         2955 non-null    string
#  48  totalTransactionRevenue    2955 non-null    string
#  49  bounces                    138231 non-null  string
#  50  campaign                   270955 non-null  string
#  51  source                     270955 non-null  string
#  52  medium                     270955 non-null  string
#  53  keyword                    104123 non-null  string
#  54  adwordsClickInfo           270955 non-null  object
#  55  isTrueDirect               84477 non-null   boolean
#  56  referralPath               89732 non-null   string
#  57  adContent                  10303 non-null   string
#  58  customDimensions_1         270955 non-null  string
#  59  criteriaParameters         270955 non-null  string
#  60  page                       11853 non-null   string
#  61  slot                       11853 non-null   string
#  62  gclId                      11882 non-null   string
#  63  adNetworkType              11853 non-null   string
#  64  isVideoAd                  11853 non-null   boolean
#  65  targetingCriteria          553 non-null     object
#  66  customDimensions_index     270955 non-null  object
# dtypes: Int32(1), Int64(4), boolean(3), object(8), string(51)
# memory usage: 134.1+ MB

# %%
df['date_cd'] = pd.to_datetime(df['date'].astype(str), format='%Y%m%d')

# %%
df['visitStartTime'].max() #1470036371 (min)  1525157802(max)
# Out:
# 1525157802

# %%
df.shape
# Out:
# (270955, 68)

# %%
numeric_train_ds = df.select_dtypes(include=[np.number])
print(numeric_train_ds.columns)

categorical_train_ds=df.select_dtypes(include=[np.object])
print(categorical_train_ds.columns)
# Out:
# Index(['date', 'visitId', 'visitNumber', 'visitStartTime', 'hits_2'], dtype='object')
# Index(['device', 'fullVisitorId', 'geoNetwork', 'totals', 'trafficSource',
#        'adwordsClickInfo', 'targetingCriteria', 'customDimensions_index'],
#       dtype='object')
